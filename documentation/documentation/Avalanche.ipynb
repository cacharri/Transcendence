# %% [markdown]
# ## Servicio blockchain levantado y operando

# %%
make logs_service SERVICE=avalanche

# %% [markdown]
# ```yaml
# blockchain  | [02-15|20:30:34.488] WARN process/process.go:92 UPnP or NAT-PMP router attach failed, you may not be listening publicly. Please confirm the settings in your router
# blockchain  | [02-15|20:30:34.491] INFO node/node.go:1229 initializing node {"version": "avalanche/1.9.2", "nodeID": "NodeID-TEkxFxAiG6w6AzurEEa1CgzvyuqwiyY9", "nodePOP": {"publicKey":"0x880b58d7afcd65db53e804f5be0678ae396d1f04a2c38f24653da292f27af54970977b46904a8c938eb2001db8d7f7e7","proofOfPossession":"0x8014fd55cc10cf773886350b84afce0b6131f4749bc19bed9d5ade07d6ecf134d3f3b0d104f203e99881c2b1e164f2b519a7e97e4acc4653f61e9f1071778e84e51da7f6cfef2ad378e209c7fbbb6212fede694b5a1bf152d325b2cc593e9559"}, "config": {"httpConfig":{"apiConfig":{"authConfig":{"apiRequireAuthToken":false},"indexerConfig":{"indexAPIEnabled":false,"indexAllowIncomplete":false},"ipcConfig":{"ipcAPIEnabled":false,"ipcPath":"/tmp","ipcDefaultChainIDs":null},"adminAPIEnabled":false,"infoAPIEnabled":true,"keystoreAPIEnabled":true,"metricsAPIEnabled":true,"healthAPIEnabled":true},"httpHost":"127.0.0.1","httpPort":9650,"httpsEnabled":false,"apiAllowedOrigins":["*"],"shutdownTimeout":10000000000,"shutdownWait":0},"ipConfig":{"ip":{"ip":"172.18.0.3","port":9651},"ipResolutionFrequency":300000000000,"attemptedNATTraversal":true},"stakingConfig":{"uptimeRequirement":0.8,"minValidatorStake":2000000000000,"maxValidatorStake":3000000000000000,"minDelegatorStake":25000000000,"minDelegationFee":20000,"minStakeDuration":1209600000000000,"maxStakeDuration":31536000000000000,"rewardConfig":{"maxConsumptionRate":120000,"minConsumptionRate":100000,"mintingPeriod":31536000000000000,"supplyCap":720000000000000000},"enableStaking":true,"disabledStakingWeight":100,"stakingKeyPath":"/avalanchego/staking/staker.key","stakingCertPath":"/avalanchego/staking/staker.crt","stakingSignerPath":"/avalanchego/staking/signer.key"},"txFeeConfig":{"txFee":1000000,"createAssetTxFee":10000000,"createSubnetTxFee":1000000000,"transformSubnetTxFee":10000000000,"createBlockchainTxFee":1000000000,"addPrimaryNetworkValidatorFee":0,"addPrimaryNetworkDelegatorFee":0,"addSubnetValidatorFee":1000000,"addSubnetDelegatorFee":1000000},"stateSyncConfig":{"stateSyncIDs":null,"stateSyncIPs":null},"bootstrapConfig":{"retryBootstrap":true,"retryBootstrapWarnFrequency":50,"bootstrapBeaconConnectionTimeout":60000000000,"bootstrapAncestorsMaxContainersSent":2000,"bootstrapAncestorsMaxContainersReceived":2000,"bootstrapMaxTimeGetAncestors":50000000,"bootstrapIDs":["NodeID-kZNuQMHhydefgnwjYX1fhHMpRNAs9my1","NodeID-QKGoUvqcgormCoMj6yPw9isY7DX9H4mdd","NodeID-FGRoKnyYKFWYFMb6Xbocf4hKuyCBENgWM","NodeID-HsBEx3L71EHWSXaE6gvk2VsNntFEZsxqc","NodeID-A7GwTSd47AcDVqpTVj7YtxtjHREM33EJw"],"bootstrapIPs":[{"ip":"18.158.15.12","port":9651},{"ip":"18.162.161.230","port":9651},{"ip":"122.248.200.212","port":9651},{"ip":"3.106.25.139","port":9651},{"ip":"3.21.38.33","port":9651}]},"databaseConfig":{"path":"/avalanchego/db/mainnet","name":"leveldb"},"avaxAssetID":"FvwEAhmxKfeiG8SnEvq42hc6whRyY3EFYAvebMqDNDGCgxN5Z","networkID":1,"healthCheckFreq":30000000000,"networkConfig":{"healthConfig":{"minConnectedPeers":1,"maxTimeSinceMsgReceived":60000000000,"maxTimeSinceMsgSent":60000000000,"maxPortionSendQueueBytesFull":0.9,"maxSendFailRate":0.9,"sendFailRateHalflife":10000000000},"peerListGossipConfig":{"peerListNumValidatorIPs":15,"peerListValidatorGossipSize":20,"peerListNonValidatorGossipSize":0,"peerListPeersGossipSize":10,"peerListGossipFreq":60000000000},"timeoutConfigs":{"pingPongTimeout":30000000000,"readHandshakeTimeout":15000000000},"delayConfig":{"initialReconnectDelay":1000000000,"maxReconnectDelay":3600000000000},"throttlerConfig":{"inboundConnUpgradeThrottlerConfig":{"upgradeCooldown":10000000000,"maxRecentConnsUpgraded":2560},"inboundMsgThrottlerConfig":{"byteThrottlerConfig":{"vdrAllocSize":33554432,"atLargeAllocSize":6291456,"nodeMaxAtLargeBytes":2097152},"bandwidthThrottlerConfig":{"bandwidthRefillRate":524288,"bandwidthMaxBurstRate":2097152},"cpuThrottlerConfig":{"maxRecheckDelay":5000000000},"diskThrottlerConfig":{"maxRecheckDelay":5000000000},"maxProcessingMsgsPerNode":1024},"outboundMsgThrottlerConfig":{"vdrAllocSize":33554432,"atLargeAllocSize":33554432,"nodeMaxAtLargeBytes":2097152},"maxInboundConnsPerSec":256},"dialerConfig":{"throttleRps":50,"connectionTimeout":30000000000},"tlsKeyLogFile":"","namespace":"","myNodeID":"NodeID-111111111111111111116DBWJs","myIP":null,"networkID":0,"maxClockDifference":60000000000,"pingFrequency":22500000000,"allowPrivateIPs":true,"compressionEnabled":true,"uptimeMetricFreq":30000000000,"requireValidatorToConnect":false,"maximumInboundMessageTimeout":10000000000,"peerReadBufferSize":8192,"peerWriteBufferSize":8192},"gossipConfig":{"gossipAcceptedFrontierValidatorSize":0,"gossipAcceptedFrontierNonValidatorSize":0,"gossipAcceptedFrontierPeerSize":15,"gossipOnAcceptValidatorSize":0,"gossipOnAcceptNonValidatorSize":0,"gossipOnAcceptPeerSize":10,"appGossipValidatorSize":10,"appGossipNonValidatorSize":0,"appGossipPeerSize":0},"adaptiveTimeoutConfig":{"initialTimeout":5000000000,"minimumTimeout":2000000000,"maximumTimeout":10000000000,"timeoutCoefficient":2,"timeoutHalflife":300000000000},"benchlistConfig":{"threshold":10,"minimumFailingDuration":150000000000,"duration":900000000000,"maxPortion":0.08333333333333333},"profilerConfig":{"dir":"/avalanchego/profiles","enabled":false,"freq":900000000000,"maxNumFiles":5},"loggingConfig":{"maxSize":8,"maxFiles":7,"maxAge":0,"directory":"/avalanchego/logs","compress":false,"disableWriterDisplaying":false,"logLevel":"INFO","displayLevel":"INFO","logFormat":"PLAIN"},"pluginDir":"/avalanchego/plugins","fdLimit":32768,"consensusParams":{"k":20,"alpha":15,"betaVirtuous":15,"betaRogue":20,"concurrentRepolls":4,"optimalProcessing":50,"maxOutstandingItems":1024,"maxItemProcessingTime":120000000000,"mixedQueryNumPushVdr":10,"mixedQueryNumPushNonVdr":0,"parents":5,"batchSize":30},"meterVMEnabled":true,"routerHealthConfig":{"maxDropRate":1,"maxDropRateHalflife":10000000000,"maxOutstandingRequests":1024,"maxOutstandingDuration":300000000000,"maxRunTimeRequests":10000000000},"consensusShutdownTimeout":30000000000,"consensusGossipFreq":10000000000,"whitelistedSubnets":[],"subnetConfigs":{},"systemTrackerProcessingHalflife":15000000000,"systemTrackerFrequency":500000000,"systemTrackerCPUHalflife":15000000000,"systemTrackerDiskHalflife":60000000000,"cpuTargeterConfig":{"vdrAlloc":8,"maxNonVdrUsage":6.4,"maxNonVdrNodeUsage":1},"diskTargeterConfig":{"vdrAlloc":1073741824000,"maxNonVdrUsage":1073741824000,"maxNonVdrNodeUsage":1073741824000},"requiredAvailableDiskSpace":536870912,"warningThresholdAvailableDiskSpace":1073741824,"traceConfig":{"exporterConfig":{"type":"unknown","endpoint":"","headers":null,"insecure":false},"enabled":false,"traceSampleRate":0},"minPercentConnectedStakeHealthy":{"11111111111111111111111111111111LpoYY":0.8}}}
# blockchain  | [02-15|20:30:34.493] INFO node/node.go:589 initializing API server
# blockchain  | [02-15|20:30:34.493] INFO server/server.go:138 API created {"allowedOrigins": ["*"]}
# blockchain  | [02-15|20:30:34.500] INFO node/node.go:896 initializing metrics API
# blockchain  | [02-15|20:30:34.500] INFO server/server.go:298 adding route {"url": "/ext/metrics", "endpoint": ""}
# blockchain  | [02-15|20:30:34.501] INFO leveldb/db.go:202 creating leveldb {"config": {"blockCacheCapacity":12582912,"blockSize":0,"compactionExpandLimitFactor":0,"compactionGPOverlapsFactor":0,"compactionL0Trigger":0,"compactionSourceLimitFactor":0,"compactionTableSize":0,"compactionTableSizeMultiplier":0,"compactionTableSizeMultiplierPerLevel":null,"compactionTotalSize":0,"compactionTotalSizeMultiplier":0,"disableSeeksCompaction":true,"openFilesCacheCapacity":1024,"writeBuffer":6291456,"filterBitsPerKey":10,"maxManifestFileSize":9223372036854775807,"metricUpdateFrequency":10000000000}}
# blockchain  | [02-15|20:30:34.520] INFO node/node.go:479 initializing database {"dbVersion": "v1.4.5"}
# blockchain  | [02-15|20:30:34.534] INFO node/node.go:850 initializing keystore
# blockchain  | [02-15|20:30:34.534] INFO node/node.go:861 initializing keystore API
# blockchain  | [02-15|20:30:34.535] INFO server/server.go:298 adding route {"url": "/ext/keystore", "endpoint": ""}
# blockchain  | [02-15|20:30:34.535] INFO node/node.go:842 initializing SharedMemory
# blockchain  | [02-15|20:30:34.537] INFO node/node.go:222 initializing networking {"currentNodeIP": "172.18.0.3:9651"}
# blockchain  | [02-15|20:30:34.538] INFO node/node.go:1016 initializing Health API
# blockchain  | [02-15|20:30:34.538] INFO server/server.go:298 adding route {"url": "/ext/health", "endpoint": ""}
# blockchain  | [02-15|20:30:34.539] INFO server/server.go:298 adding route {"url": "/ext/health", "endpoint": "/readiness"}
# blockchain  | [02-15|20:30:34.539] INFO server/server.go:298 adding route {"url": "/ext/health", "endpoint": "/health"}
# blockchain  | [02-15|20:30:34.539] INFO server/server.go:298 adding route {"url": "/ext/health", "endpoint": "/liveness"}
# blockchain  | [02-15|20:30:34.539] INFO node/node.go:636 adding the default VM aliases
# blockchain  | [02-15|20:30:34.875] INFO node/node.go:754 initializing VMs
# blockchain  | [02-15|20:30:34.875] INFO server/server.go:298 adding route {"url": "/ext/vm/rWhpuQPF1kb72esV2momhMuTYGkEb1oL29pt2EBXWmSy4kxnT", "endpoint": ""}
# blockchain  | [02-15|20:30:34.876] INFO server/server.go:298 adding route {"url": "/ext/vm/jvYyfQTxGMJLuGWa55kdP2p2zSUYsQ5Raupu4TW34ZAUBAbtq", "endpoint": ""}
# blockchain  | [02-15|20:30:34.876] INFO server/server.go:298 adding route {"url": "/ext/vm/mgj786NP7uDwBCcq6YwThhaN8FLyybkCa4zBWTQbNgmK6k9A6", "endpoint": "/rpc"}
# blockchain  | [02-15|20:30:34.878] INFO node/node.go:916 skipping admin API initialization because it has been disabled
# blockchain  | [02-15|20:30:34.878] INFO node/node.go:968 initializing info API
# blockchain  | [02-15|20:30:34.879] INFO server/server.go:298 adding route {"url": "/ext/info", "endpoint": ""}
# blockchain  | [02-15|20:30:34.880] INFO node/node.go:1119 skipping ipc API initialization because it has been disabled
# blockchain  | [02-15|20:30:34.880] INFO node/node.go:1132 initializing chain aliases
# blockchain  | [02-15|20:30:35.055] INFO node/node.go:1150 initializing API aliases
# blockchain  | [02-15|20:30:35.215] INFO node/node.go:941 skipping profiler initialization because it has been disabled
# blockchain  | [02-15|20:30:35.216] INFO node/node.go:573 initializing chains
# blockchain  | [02-15|20:30:35.216] INFO chains/manager.go:291 creating chain {"subnetID": "11111111111111111111111111111111LpoYY", "chainID": "11111111111111111111111111111111LpoYY", "vmID": "rWhpuQPF1kb72esV2momhMuTYGkEb1oL29pt2EBXWmSy4kxnT"}
# blockchain  | [02-15|20:30:35.324] INFO <P Chain> platformvm/vm.go:228 initializing last accepted {"blkID": "2FUFPVPxbTpKNn39moGSzsmGroYES4NZRdw3mJgNvMkMiMHJ9e"}
# blockchain  | [02-15|20:30:35.325] INFO <P Chain> snowman/transitive.go:81 initializing consensus engine
# blockchain  | [02-15|20:30:35.327] INFO <P Chain> bootstrap/bootstrapper.go:121 starting bootstrapper
# blockchain  | [02-15|20:30:35.328] INFO server/server.go:272 adding route {"url": "/ext/bc/11111111111111111111111111111111LpoYY", "endpoint": ""}
# blockchain  | [02-15|20:30:35.328] INFO chains/manager.go:1072 starting chain creator
# blockchain  | [02-15|20:30:35.329] INFO server/server.go:173 HTTP API server listening {"host": "127.0.0.1", "port": 9650}
# ```

# %% [markdown]
# Parece que el nodo Avalanche está iniciando correctamente. Se están configurando las APIs de la blockchain, como la API de métricas, keystore, health, y algunas APIs para máquinas virtuales. También se muestra un mensaje de advertencia relacionado con UPnP o NAT-PMP, indicando que el nodo podría no estar siendo accesible públicamente, lo que podrías revisar si planeas que el nodo esté disponible de manera pública.
#
# Específicamente, los logs muestran que el nodo está funcionando con la versión "avalanche/1.9.2" y que se están inicializando correctamente diversas partes del sistema, como la base de datos, el keystore, la red y las rutas de la API. Algunas características, como la API de administración, han sido deshabilitadas, lo que puede ser esperado si has configurado el nodo para mayor seguridad.
#
# ## Advertencia sobre UPnP o NAT-PMP
# La advertencia sobre UPnP o NAT-PMP ("UPnP or NAT-PMP router attach failed") indica que el nodo puede no estar accesible desde fuera de tu red local. Si necesitas que otros nodos se conecten a tu nodo, podrías verificar la configuración de tu enrutador o firewall para asegurarte de que se permiten las conexiones a los puertos correctos, en particular el puerto 9651.
#
# En resumen, parece que el nodo está operativo. Si necesitas que sea accesible públicamente, es recomendable revisar la configuración de la red para permitir el tráfico entrante.
